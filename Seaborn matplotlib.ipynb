# %% [markdown]
# __Seaborn__ is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Seaborn built in datasets

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')

# %%
crash_df.head(1)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332     5.64          18.048        15.04       784.55
#
#    ins_losses abbrev
# 0      145.08     AL

# %% [markdown]
# # Distribution Plot

# %%
sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# Out:
# C:\Users\any\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %%
sns.histplot(crash_df['not_distracted'], kde=True, stat="density", linewidth=0, bins=25)
# Out:
# <AxesSubplot:xlabel='not_distracted', ylabel='Density'>

# %% [markdown]
# # Join Plot

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='kde')

# %%
sns.jointplot(x='speeding', y='ins_premium', data=crash_df, kind='hex')

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Pair Plots

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
sns.pairplot(tips_df, hue='sex', palette='Blues')
sns.set_context(font_scale=1.4)

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # Styling

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(8, 4))

sns.set_context('talk', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

sns.despine(left=True)
sns.despine(bottom=True)

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(6, 1))
sns.set_context(font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %% [markdown]
# # Bar Plots

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='sex', data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

sns.set(rc={'figure.figsize':(11.7, 8.7)})

# %% [markdown]
# # Violin Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex')

# Violin us isuing the KDE(kernel density estimation) estimation
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Strip Plot

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue='sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Swarm Plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df)
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='white')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Palettes

# %%
plt.figure(figsize=(8, 7))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='afmhot', dodge=True)

plt.legend(loc=0)

# %% [markdown]
# # Heatmaps

# %%
plt.figure(figsize=(8, 6))
sns.set_context('paper', font_scale=1.4)

crash_mx = crash_df.corr()

# more colors https://matplotlib.org/stable/tutorials/colors/colormaps.html
sns.heatmap(crash_mx, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns='year', values='passengers')
flights

sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=0.7)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # Cluster Map

# %%
iris = sns.load_dataset('iris')

spacies = iris.pop('species')
sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap='Blues', standard_scale=1)

# %% [markdown]
# # Pair Grid

# %%
iris = sns.load_dataset('iris')
# iris_g = sns.PairGrid(iris, hue='species')
# #iris_g.map(plt.scatter)
# iris_g.map_diag(plt.hist)
# iris_g.map_offdiag(plt.scatter)

# iris_g.map_upper(plt.scatter)
# iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue='species', 
                      x_vars=['sepal_length', 'sepal_width'],
                      y_vars=['petal_length', 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %%
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue='species')
#iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)
iris_g.map_offdiag(plt.scatter)

iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)
# iris_g = sns.PairGrid(iris, hue='species', 
#                       x_vars=['sepal_length', 'sepal_width'],
#                       y_vars=['petal_length', 'petal_width'])
# iris_g.map(plt.scatter)
# iris_g.add_legend()

# %% [markdown]
# # Facet Grid

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=8)

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1)
tips_fg.map(plt.scatter, 'total_bill', 'tip')
plt.legend(loc=0)

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', hue='smoker', height=4, aspect=1,
                       col_order=['Dinner', 'Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')
plt.legend(loc=0)

# %%
kws = dict(s=50, linewidth=5)
tips_fg = sns.FacetGrid(tips_df, col='sex', hue='smoker', height=4, aspect=1.3,
                       hue_order=['Yes', 'No'],
                       hue_kws=dict(marker=['^', 'v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws)

# %%
att_df = sns.load_dataset('attention')
att_fg = sns.FacetGrid(att_df, col='subject', col_wrap=5, height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker= '.')

# %% [markdown]
# # Regression Plots

# %%
tips_df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
plt.figure(figsize=(8, 6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o', '^'],
          scatter_kws={'s':100, 'linewidth': 0.5, 'edgecolor': 'w'})

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time',data=tips_df)
